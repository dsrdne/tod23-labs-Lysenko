# %% [markdown]
# #### Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
f = pd.read_csv('sp500hst.txt', delimiter=',')
f.columns=['date', 'ticker', 'open', 'high', 'low', 'close', 'volume']
f
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090824      A  25.64  25.7400  25.330  25.50   22247
# 1       20090825      A  25.50  25.7000  25.225  25.34   30891
# 2       20090826      A  25.32  25.6425  25.145  25.48   33334
# 3       20090827      A  25.50  25.5700  25.230  25.54   70176
# 4       20090828      A  25.67  26.0500  25.630  25.83   39694
# ...          ...    ...    ...      ...     ...    ...     ...
# 122568  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122569  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122570  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122571  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122572  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122573 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
sr_open=f['open'].mean()
print(f'Cреднее по 3 столбцу - {sr_open}')
sr_high=f['high'].mean()
print(f'Cреднее по 4 столбцу - {sr_high}')
sr_low=f['low'].mean()
print(f'Cреднее по 5 столбцу - {sr_low}')
sr_close=f['close'].mean()
print(f'Cреднее по 6 столбцу - {sr_close}')
# Out:
# Cреднее по 3 столбцу - 42.59559631484943
# Cреднее по 4 столбцу - 43.10238609645113
# Cреднее по 5 столбцу - 42.054601007561544
# Cреднее по 6 столбцу - 42.60200396416825

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
m=np.array(list(f['date'].items()), dtype=str)
lst=[]
for i in range(len(m[:,1])):
    lst.append(int(m[:,1][i][4:6]))
f['month']=lst
f
# Out:
#             date ticker   open     high     low  close  volume  month
# 0       20090824      A  25.64  25.7400  25.330  25.50   22247      8
# 1       20090825      A  25.50  25.7000  25.225  25.34   30891      8
# 2       20090826      A  25.32  25.6425  25.145  25.48   33334      8
# 3       20090827      A  25.50  25.5700  25.230  25.54   70176      8
# 4       20090828      A  25.67  26.0500  25.630  25.83   39694      8
# ...          ...    ...    ...      ...     ...    ...     ...    ...
# 122568  20100813    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122569  20100816    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122570  20100817    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122571  20100819    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122572  20100820    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122573 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
f.groupby(f['ticker']).size()
# Out:
# ticker
# A       244
# AA      245
# AAPL    241
# ABC     245
# ABT     245
#        ...
# XTO     207
# YHOO    243
# YUM     245
# ZION    244
# ZMH     245
# Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
f1=pd.read_csv('sp_data2.csv', delimiter=';', names=['ticker', 'decoding', 'percent'])
merged=pd.merge(f, f1[['ticker', 'decoding']], how= 'outer' )
merged
# Out:
#               date ticker   open     high     low  close   volume  month  \
# 0       20090824.0      A  25.64  25.7400  25.330  25.50  22247.0    8.0
# 1       20090825.0      A  25.50  25.7000  25.225  25.34  30891.0    8.0
# 2       20090826.0      A  25.32  25.6425  25.145  25.48  33334.0    8.0
# 3       20090827.0      A  25.50  25.5700  25.230  25.54  70176.0    8.0
# 4       20090828.0      A  25.67  26.0500  25.630  25.83  39694.0    8.0
# ...            ...    ...    ...      ...     ...    ...      ...    ...
# 122731         NaN     FL    NaN      NaN     NaN    NaN      NaN    NaN
# 122732         NaN    NFX    NaN      NaN     NaN    NaN      NaN    NaN
# 122733         NaN   EVHC    NaN      NaN     NaN    NaN      NaN    NaN
# 122734         NaN    BHF    NaN      NaN     NaN    NaN      NaN    NaN
# 122735         NaN    AYI    NaN      NaN     NaN    NaN      NaN    NaN
#
#                      decoding
# 0        Agilent Technologies
# ...

# %% [markdown]
# ## Лабораторная работа №2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv', delimiter=',')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
reviews = pd.read_csv('reviews_sample.csv', delimiter=',')
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
r1=recipes.shape
print(f' Количество строчек в таблице "рецепты" - {r1[0]}. Количество столбцов в таблице "рецепты" - {r1[1]}. \n Типы данных в таблице - ')
print (recipes.dtypes)
# Out:
#  Количество строчек в таблице "рецепты" - 30000. Количество столбцов в таблице "рецепты" - 8.
#  Типы данных в таблице -
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object

# %%
r2=reviews.shape
print(f' Количество строчек в таблице "обзоры" - {r2[0]}. Количество столбцов в таблице "обзоры" - {r2[1]}. \n Типы данных в таблице - ')
print (reviews.dtypes)
# Out:
#  Количество строчек в таблице "обзоры" - 126696. Количество столбцов в таблице "обзоры" - 6.
#  Типы данных в таблице -
# Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('Количество пропусков в столбцах таблицы "рецепты" -')
print(recipes.isnull().sum())
# Out:
# Количество пропусков в столбцах таблицы "рецепты" -
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64

# %%
d1=(recipes.isnull().sum().sum())/recipes.shape[0]*recipes.shape[1]
print(f'Доля строк, содержащих пропуски - {d1}')
# Out:
# Доля строк, содержащих пропуски - 5.518133333333333

# %%
print('Количество пропусков в столбцах таблицы "обзоры" -')
print(reviews.isnull().sum())
# Out:
# Количество пропусков в столбцах таблицы "обзоры" -
# Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64

# %%
d2 = (reviews.isnull().sum().sum())/(reviews.shape[0]*reviews.shape[1])
print(f'Доля строк, содержащих пропуски - {d2}')
# Out:
# Доля строк, содержащих пропуски - 2.2363242196543958e-05

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
sr_min=recipes['minutes'].mean()
print(f'Cреднее время приготовления - {sr_min}')
sr_ing=recipes['n_ingredients'].mean()
print(f'Cреднее количество ингредиентов - {sr_ing}')
# Out:
# Cреднее время приготовления - 123.35813333333333
# Cреднее количество ингредиентов - 9.008285984848484

# %%
sr_rat = reviews['rating'].mean()
print(f'Средний рейтинг - {sr_rat}')
# Out:
# Средний рейтинг - 4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
pd.DataFrame(recipes.sample(n=10))
# Out:
#                                                     name      id  minutes  \
# 2970   better squash casserole  no bread crumbs  crac...  114422       40
# 10052                    easy homemade salsa for canning  328559       65
# 21632                   pulled barbecued beef sandwiches  451490      330
# 18121             moroccan couscous salad with baby corn   40926       20
# 26570              sweet   savory roasted spiced walnuts  442249       45
# 19889                       parsnip and celery root mash  380097       45
# 882                                  apple crumbles cake  437715       80
# 4063       buffalo chicken sandwiches  rachael ray style  216796       30
# 5553                         chicken and asparagus rolls  257346       60
# 22765  roasted fish with charmoula  tomatoes and pota...  140690       80
#
#        contributor_id   submitted  n_steps  \
# 2970           203823  2005-03-27      8.0
# 10052          386849  2008-10-02      NaN
# ...

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.rename(columns = {'Unnamed: 0':'id'}, inplace = True )
reviews_r = reviews.copy()
reviews_r['id'] = np.arange(len(reviews['id']))
reviews_r
# Out:
#             id     user_id  recipe_id        date  rating  \
# 0            0       21752      57993  2003-05-01       5
# 1            1      431813     142201  2007-09-16       5
# 2            2      400708     252013  2008-01-10       4
# 3            3  2001852463     404716  2017-12-11       5
# 4            4       95810     129396  2008-03-14       5
# ...        ...         ...        ...         ...     ...
# 126691  126691     1270706     335534  2009-05-17       4
# 126692  126692     2282344       8701  2012-06-03       0
# 126693  126693      689540     222001  2008-04-08       5
# 126694  126694  2000242659     354979  2015-06-02       5
# 126695  126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
srtd1 = recipes.loc[recipes["minutes"] <= 20]
srtd = srtd1.loc[srtd1["n_ingredients"] <= 5]
srtd
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = recipes['submitted'].astype("datetime64[ns]")

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
bef2010 = recipes.loc[recipes['submitted'].dt.year <= 2010]
bef2010
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length']=recipes['description'].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name']=recipes['name'].str.title()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count']=recipes['name'].str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
max_recipes=pd.DataFrame(recipes['contributor_id'].value_counts())
max_recipes
# Out:
#          contributor_id
# 89831               421
# 37449               346
# 37779               345
# 1533                186
# 169430              183
# ...                 ...
# 1061628               1
# 1076183               1
# 429061                1
# 64032                 1
# 186118                1
#
# [8404 rows x 1 columns]

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
mean_rating=reviews.groupby('recipe_id')['rating'].mean()
print(mean_rating)
no_rating= reviews.review.isnull().sum()
print(f'Отзывов нет у {no_rating} рецептов')
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64
# Отзывов нет у 17 рецептов

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes.groupby(recipes['submitted'].dt.year).size()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
reviews.rename(columns = {'Unnamed: 0':'id'}, inplace = True )
merged=pd.merge(recipes, reviews, how= 'outer' )
merged=merged[['id', 'name', 'user_id', 'rating']]
merged
# Out:
#              id                                      name       user_id  \
# 0         44123     george s at the cove  black bean soup           NaN
# 1         67664        healthy for them  yogurt popsicles           NaN
# 2         38798              i can t believe it s spinach           NaN
# 3         35173                      italian  gut busters  2.000576e+09
# 4         84797  love is in the air  beef fondue   sauces           NaN
# ...         ...                                       ...           ...
# 153240  1013457                                       NaN  1.270706e+06
# 153241   158736                                       NaN  2.282344e+06
# 153242  1059834                                       NaN  6.895400e+05
# 153243   453285                                       NaN  2.000243e+09
# 153244   691207                                       NaN  4.634350e+05
#
#         rating
# 0          NaN
# 1          NaN
# 2          NaN
# 3          1.0
# 4          NaN
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
re_count= reviews['recipe_id'].value_counts()
rew_count=re_count.to_frame()
rew_count.reset_index(inplace= True )
rew_count.columns = ['id', 'review_count']
rew_count
# Out:
#            id  review_count
# 0       27208          1382
# 1       82102           708
# 2      135350           674
# 3      107786           592
# 4       50719           486
# ...       ...           ...
# 28095   23964             1
# 28096  499966             1
# 28097  418761             1
# 28098  430164             1
# 28099  296868             1
#
# [28100 rows x 2 columns]

# %%
new_df=pd.merge(merged, rew_count, how= 'outer' )[['name', 'id', 'review_count']]
new_df['review_count'] = new_df['review_count'].fillna (0)
new_df
# Out:
#                                             name       id  review_count
# 0          george s at the cove  black bean soup    44123           3.0
# 1             healthy for them  yogurt popsicles    67664           8.0
# 2                   i can t believe it s spinach    38798           3.0
# 3                           italian  gut busters    35173           1.0
# 4       love is in the air  beef fondue   sauces    84797           8.0
# ...                                          ...      ...           ...
# 153240                                       NaN  1013457           0.0
# 153241                                       NaN   158736           0.0
# 153242                                       NaN  1059834           0.0
# 153243                                       NaN   453285           0.0
# 153244                                       NaN   691207           0.0
#
# [153245 rows x 3 columns]

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews['date'] = pd.to_datetime(recipes.submitted)
yearsrate = reviews['rating'].groupby(reviews.date.dt.year).mean().sort_values()
yearsrate
# Out:
# date
# 2017.0    4.051282
# 2016.0    4.208333
# 2013.0    4.363265
# 2001.0    4.380306
# 2003.0    4.383462
# 2006.0    4.389577
# 2015.0    4.404762
# 2007.0    4.406864
# 2012.0    4.414264
# 2018.0    4.416667
# 2008.0    4.422189
# 2009.0    4.424232
# 2002.0    4.434569
# 2010.0    4.438231
# 2011.0    4.441432
# 2004.0    4.455643
# 2005.0    4.464856
# 1999.0    4.476364
# 2014.0    4.517986
# 2000.0    4.576923
# Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes.sort_values(by=['name_word_count'], ascending=False, inplace=True)
recipes
# Out:
#                                                     name      id  minutes  \
# 26223  subru uncle s whole green moong dal i ll be ma...   77188       95
# 26222  subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  top secret recipes version of  i h o p  griddl...  113346       20
# 28083  tsr version of t g i  friday s black bean soup...  102274       75
# 22778  roasted garlic stuffed steak with garlic mashe...   38409       85
# ...                                                  ...     ...      ...
# 23016                                             rotini  207839       35
# 23063                                             runzas   55733       45
# 4340                                              caesar   52399        1
# 21111                                           pomidori  353387        2
# 4710                                            caramels  143615       30
#
#        contributor_id   submitted  n_steps  \
# ...

# %%
recipes.to_csv('recipesrecipes.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("file.xlsx") as writer:
    merged.to_excel(writer, sheet_name="Рецепты с оценками")
    rew_count.to_excel(writer, sheet_name="Количество отзывов по рецептам")
