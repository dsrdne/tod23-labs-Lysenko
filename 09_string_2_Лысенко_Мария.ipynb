# %% [markdown]
# # Введение в обработку текста на естественном языке

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 9: Введение в обработку текста на естественном языке\
# * https://realpython.com/nltk-nlp-python/
# * https://scikit-learn.org/stable/modules/feature_extraction.html

# %% [markdown]
# ## Задачи для совместного разбора

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pymorphy2

# %%
from nltk.metrics import edit_distance
from nltk.corpus import words

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Маша\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
import nltk
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Маша\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Маша\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# 1. Считайте слова из файла `litw-win.txt` и запишите их в список `words`. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка `words`. Считайте, что в слове есть опечатка, если данное слово не содержится в списке `words`.

# %%
text = '''с велечайшим усилием выбравшись из потока убегающих людей Кутузов со свитой уменьшевшейся вдвое поехал на звуки выстрелов русских орудий'''

# %% [markdown]
# 2. Разбейте текст из формулировки задания 1 на слова; проведите стемминг и лемматизацию слов.

# %%
txt='Считайте слова из файла litw-win.txt и запишите их в список words. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка words. Считайте, что в слове есть опечатка, если данное слово не содержится в списке words.'

# %%
stemmer = SnowballStemmer("russian")
lemmatizer = WordNetLemmatizer()

# формулировка задания 1))))=
text = 'Считайте слова из файла litw-win.txt и запишите их в список words. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка words. Считайте, что в слове есть опечатка, если данное слово не содержится в списке words.'


tokens = word_tokenize(text)
stemmed_words = [stemmer.stem(token) for token in tokens]
lemmatized_words = [lemmatizer.lemmatize(token) for token in tokens]

print("Исходный текст:", text)
print("Список слов:", tokens)
print("Стемминг слов:", stemmed_words)
print("Лемматизация слов:", lemmatized_words)
# Out:
# Исходный текст: Считайте слова из файла litw-win.txt и запишите их в список words. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка words. Считайте, что в слове есть опечатка, если данное слово не содержится в списке words.
# Список слов: ['Считайте', 'слова', 'из', 'файла', 'litw-win.txt', 'и', 'запишите', 'их', 'в', 'список', 'words', '.', 'В', 'заданном', 'предложении', 'исправьте', 'все', 'опечатки', ',', 'заменив', 'слова', 'с', 'опечатками', 'на', 'ближайшие', '(', 'в', 'смысле', 'расстояния', 'Левенштейна', ')', 'к', 'ним', 'слова', 'из', 'списка', 'words', '.', 'Считайте', ',', 'что', 'в', 'слове', 'есть', 'опечатка', ',', 'если', 'данное', 'слово', 'не', 'содержится', 'в', 'списке', 'words', '.']
# Стемминг слов: ['счита', 'слов', 'из', 'файл', 'litw-win.txt', 'и', 'запиш', 'их', 'в', 'список', 'words', '.', 'в', 'зада', 'предложен', 'исправьт', 'все', 'опечатк', ',', 'замен', 'слов', 'с', 'опечатк', 'на', 'ближайш', '(', 'в', 'смысл', 'расстоян', 'левенштейн', ')', 'к', 'ним', 'слов', 'из', 'списк', 'words', '.', 'счита', ',', 'что', 'в', 'слов', 'ест', 'опечатк', ',', 'есл', 'дан', 'слов', 'не', 'содерж', 'в', 'списк', 'words', '.']
# Лемматизация слов: ['Считайте', 'слова', 'из', 'файла', 'litw-win.txt', 'и', 'запишите', 'их', 'в', 'список', 'word', '.', 'В', 'заданном', 'предложении', 'исправьте', 'все', 'опечатки', ',', 'заменив', 'слова', 'с', 'опечатками', 'на', 'ближайшие', '(', 'в', 'смысле', 'расстояния', 'Левенштейна', ')', 'к', 'ним', 'слова', 'из', 'списка', 'word', '.', 'Считайте', ',', 'что', 'в', 'слове', 'есть', 'опечатка', ',', 'если', 'данное', 'слово', 'не', 'содержится', 'в', 'списке', 'word', '.']

# %% [markdown]
# 3. Преобразуйте предложения из формулировки задания 1 в векторы при помощи `CountVectorizer`.

# %% [markdown]
# ## Лабораторная работа 9

# %%
import csv
from nltk.tokenize import word_tokenize
import random

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Маша\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# ### Расстояние редактирования

# %% [markdown]
# 1.1 Загрузите предобработанные описания рецептов из файла `preprocessed_descriptions.csv`. Получите набор уникальных слов `words`, содержащихся в текстах описаний рецептов (воспользуйтесь `word_tokenize` из `nltk`).

# %%
with open('preprocessed_descriptions.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)
    wordsinprep = set()
    for row in reader:
        description = row[2]
        tokens = word_tokenize(description)
        wordsinprep.update(tokens)

print(wordsinprep)
# Out:
# {'cames', 'donkeys', 'happen', 'sameold', 'shelves', 'alternate', 'brew', 'featured', 'cordials', 'etouffeesort', 'doanleigh', 'improvises', 'trusty', 'tamari', 'volunteered', 'recipe2', 'moistens', 'haley', 'wal', '37th', 'presbyterian', 'cupfull', 'daymy', 'extreme', 'infresh', 'carmen', 'minty', 'braidwoods', 'assignment', 'jot', 'yesterdays', 'mangiamangia', 'recipethis', 'wwwshopworldkitchencom', 'curb', 'juicessometimes', 'pacakges', 'greenspans', 'devilish', 'admitted', 'recipe186700', 'merit', 'cleary', 'gaapril', 'crafts', 'harming', 'myselfsince', 'familiar', 'guard', 'bank', 'gettogethers', 'lion', 'encrusted', 'gratedoh', 'dominick', 'ddil', 'turns', 'ingrediets', 'had', 'cooperatives', 'deliciouspg', 'eatingany', 'trots', 'factorys', 'fillingthis', 'lorraine', 'prunes', 'panningtheglobecom', 'fortunate', 'resultswhen', 'rave', 'confident', 'retitled', 'filipinostyle', 'raspstyle', 'gallops', 'sharingvegeta', 'acidy', 'soupfeel', 'cutty', 'earth', 'mosca', 'hornswagglecheat', 'aversion', 'singla', 'radar', 'fifth', 'grows', 'bs', 'hops', 'ptsserving', 'dress', 'omaha', 'sb', 'nightthis', 'nottoobitter', 'portale', 'withthe', 'these', 'thisthere', 'meateating', 'snackfleur', 'out', 'expensive', '464144', 'junior', 'beti', 'spencer', 'thicktextured', 'uptondunning', 'rest', 'macdonald', 'httpwwwkitchenlinkcomcookbooks200003854777753html', 'atlanta', 'palatable', 'bummed', 'emmenthaler', 'moulin', 'nonexistent', 'tofutti', 'sticktoyourribs', 'swamp', 'madeyou', '060906', 'breadsrecipe', 'malgieri', 'oporto', 'fijian', 'peelthe', 'filter', 'chickeneven', 'pkg', 'foodyum', 'triple', 'uwajimaya', 'basilgreat', 'girdles', 'eaterbut', 'vital', 'moan', 'impressed', 'avocadosoranges', 'haystacks', 'vistacare', 'candys', '3abnthey', 'stern', '137', 'ubly', 'inc', 'recipe158832', 'parish', 'ihops', 'itheaven', 'mediterraneanstyle', 'deliciouseasy', 'well', 'saladlover', 'uhm', 'parens', 'pies', 'allotted', 'phyos', 'sweetens', 'africa', 'cookingcom', 'packs', 'yeastfree', 'lightness', 'cookbooka', 'crowning', 'hafners', 'nongravy', 'closeknit', 'intro', 'stationed', 'likeyou', 'lethal', 'rampage', 'charles', 'congress', 'couronne', 'poker', 'flexible', 'mealallinoneafter', 'sangrita', 'caramelizes', 'dina', 'methods', 'wwwdotokaramountainatblogspotdotcom', 'badthis', 'shooter', 'sundays', 'twisting', 'marketplace', 'burnin', 'allllthat', 'dner', 'solomons', 'doozies', 'granule', 'birdalso', 'albondigas', 'forms', 'refresher', 'samoan', 'keskeitto', 'hoursif', 'stray', 'fe', 'pa', 'bagging', 'abita', 'belonged', 'nobelpigcom', 'ohiohttpthewebgangstacomindexphp201005awardwinningrecipeforcincodemayoguacamolewithbluecheeseandbaconinspiredbyfoodnetwork', 'supped', 'pioneerwomancom', 'semihomemade', 'fasteat', 'successful', 'brilliance', 'contention', 'mid1960s', 'estimatedcook', 'lackingbut', 'beau', 'meals', 'olla', 'glebe', '196367', 'rage', 'instance', 'campion', 'tomatoey', 'pulse', 'celiac', 'huynh', 'brightens', 'boiledfried', 'chickenvisit', 'overly', '183964flour', 'englandfeel', 'silpats', 'punctuation', 'moma', 'fiji', 'szechuan', 'repeats', 'christmass', '115929', 'shitake', 'contestant', 'hafa', 'fancylooking', 'breadstick', 'boughtonly', 'goin', 'va', 'greatgrandma', 'lifetime', '1982', 'pitch', 'struggle', 'change', '3032', 'teenagers', 'finishing', '2015', 'introducing', 'linkwwwtopsecretrecipescom', 'potatotype', 'adobe', 'triedi', 'foos', 'elvisinspired', 'eliminating', 'zurita', 'only', '425', 'spears', 'indianmoroccan', 'kingsolver', 'resturant', 'crabcakes', 'quarterbacks', 'omacs', 'boughtto', 'glgg', '265630', 'mtg', 'moruga', 'outsider', 'kimiko', 'tgi', 'fernandina', 'rainford', 'coolusing', 'casas', 'households', 'guestsserve', 'merlot', 'saucing', 'tysoncom', 'shrove', 'lessas', 'mojito', 'noodleseasily', 'mackleypresent', 'jennys', 'toughest', 'symbolize', 'offset', 'hashbrows', 'rolls', 'lowi', 'miseryinducing', 'glamour', 'httpwwwamazoncomarabesquemoroccoturkeylebanonebookdpb001o1o7w6refdpkinwstrp1ieutf ...

# %% [markdown]
# 1.2 Сгенерируйте 5 пар случайно выбранных слов и посчитайте между ними расстояние редактирования.

# %%
word_pairs = random.sample(wordsinprep, k=10)
for i in range(0, len(word_pairs), 2):
    word1 = word_pairs[i]
    word2 = word_pairs[i+1]
    
    distance = edit_distance(word1, word2)
    print(f"Расстояние Левенштейна между '{word1}' и '{word2}': {distance}")
# Out:
# Расстояние Левенштейна между 'toowwwthesinglebitecom' и 'planned': 20
# Расстояние Левенштейна между 'promotion' и 'regularyoung': 10
# Расстояние Левенштейна между 'hemingway' и 'orangered': 8
# Расстояние Левенштейна между 'houlihans' и 'feijoas': 7
# Расстояние Левенштейна между 'peoplefor' и 'hamburg': 9
# C:\Users\Маша\AppData\Local\Temp\ipykernel_6856\1725817219.py:1: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   word_pairs = random.sample(wordsinprep, k=10)

# %% [markdown]
# 1.3 Напишите функцию, которая для заданного слова `word` возвращает `k` ближайших к нему слов из списка `words` (близость слов измеряется с помощью расстояния Левенштейна)

# %%
def find_closest_words(word, wordsinprep, k):
    distances = [(w, edit_distance(word, w)) for w in wordsinprep]
    sorted_distances = sorted(distances, key=lambda x: x[1])
    closest_words = [w[0] for w in sorted_distances[:k]]
    return closest_words

# %%
word = 'hello'
k = 3

# %%
closest_words = find_closest_words(word, wordsinprep, k)
print(f"Ближайшие {k} слов(а) к '{word}': {closest_words}")
# Out:
# Ближайшие 3 слов(а) к 'hello': ['hello', 'mello', 'jello']

# %% [markdown]
# ### Стемминг, лемматизация

# %%
import pandas as pd

# %% [markdown]
# 2.1 На основе результатов 1.1 создайте `pd.DataFrame` со столбцами:
#     * word
#     * stemmed_word
#     * normalized_word
#
# Столбец `word` укажите в качестве индекса.
#
# Для стемминга воспользуйтесь `SnowballStemmer`, для нормализации слов - `WordNetLemmatizer`. Сравните результаты стемминга и лемматизации.

# %%
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()
stemmed_words = [stemmer.stem(word) for word in wordsinprep]
lemmatized_words = [lemmatizer.lemmatize(word) for word in wordsinprep]
wordsinprep=list(wordsinprep)
wrr = {'stemmed_word' : stemmed_words, 'normalized_word' : lemmatized_words}
df = pd.DataFrame(wrr, index=wordsinprep)
df
# Out:
#              stemmed_word normalized_word
# cames                came           cames
# donkeys            donkey          donkey
# happen             happen          happen
# sameold           sameold         sameold
# shelves             shelv           shelf
# ...                   ...             ...
# camping              camp         camping
# detailed           detail        detailed
# pitas                pita            pita
# airy                 airi            airy
# highaltitude  highaltitud    highaltitude
#
# [32868 rows x 2 columns]

# %% [markdown]
# 2.2. Удалите стоп-слова из описаний рецептов. Какую долю об общего количества слов составляли стоп-слова? Сравните топ-10 самых часто употребляемых слов до и после удаления стоп-слов.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Маша\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in wordsinprep if word.lower() not in stop_words]
print(f'стоп-слов было {len(wordsinprep)-len(filtered_tokens)}. Они составляли {(len(wordsinprep)-len(filtered_tokens))/len(wordsinprep)} всех слов')
# Out:
# стоп-слов было 136. Они составляли 0.004137763173907752 всех слов

# %% [markdown]
# ### Векторное представление текста

# %% [markdown]
# 3.1 Выберите случайным образом 5 рецептов из набора данных. Представьте описание каждого рецепта в виде числового вектора при помощи `TfidfVectorizer`

# %% [markdown]
# 3.2 Вычислите близость между каждой парой рецептов, выбранных в задании 3.1, используя косинусное расстояние (`scipy.spatial.distance.cosine`) Результаты оформите в виде таблицы `pd.DataFrame`. В качестве названий строк и столбцов используйте названия рецептов.

# %% [markdown]
# 3.3 Какие рецепты являются наиболее похожими? Прокомментируйте результат (словами).
